# %% [markdown]
# #### Number frequency count

# %%
a =  [ 1, 2, 1, 3, 2, 1 ]
m =  [ 1, 2, 3, 4, 5 , 6]
dict = {}

for i in a:
    if i in dict:
        dict[i] += 1
    else:
        dict[i] = 1
dict
# Out:
# {1: 3, 2: 2, 3: 1}

# %% [markdown]
# #### 🔍 Dry Run Table
#
#
# | Iteration | `i` (Current Element) | Is `i` in `dict`? | Action Taken           | `dict` After Iteration |
# | --------- | --------------------- | ----------------- | ---------------------- | ---------------------- |
# | 1         | 1                     | ❌ No              | Add `1` with value `1` | `{1: 1}`               |
# | 2         | 2                     | ❌ No              | Add `2` with value `1` | `{1: 1, 2: 1}`         |
# | 3         | 1                     | ✅ Yes             | Increment value of `1` | `{1: 2, 2: 1}`         |
# | 4         | 3                     | ❌ No              | Add `3` with value `1` | `{1: 2, 2: 1, 3: 1}`   |
# | 5         | 2                     | ✅ Yes             | Increment value of `2` | `{1: 2, 2: 2, 3: 1}`   |
# | 6         | 1                     | ✅ Yes             | Increment value of `1` | `{1: 3, 2: 2, 3: 1}`   |
